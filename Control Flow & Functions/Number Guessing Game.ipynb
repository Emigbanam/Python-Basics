# %% [markdown]
# ## Number Guessing Game Build a game where the computer picks a random number and the user tries to guess it.
#
# ### Requirements:
# #### Generate a random number between 1 and 100
# - Ask the user to guess the number
# - Tell them if their guess is too high, too low, or correct
# - Keep track of the number of guesses
# - When they guess correctly, display the number of attempts
# - Ask if they want to play again
# - Use at least 3 functions (e.g., generate_number, get_guess, check_guess)

# %%
import random


def generate_number():
    return random.randint(1, 100)

def get_guess():
    guess = input("What number is it? ")
    return int(guess)


def check_guess(guess, number):
    if guess > number:
        print("Too high")
    elif guess < number:
        print("Too low")
    else:
        print("Correct!")
    return guess == number


print("====Welcome to Guesser Game====")
print("How to play. \nI will select a number and you will have to guess it")
print("Let's begin!")

while True:
    number = generate_number()
    attempts = 0

    while True:
        guess = get_guess()
        attempts += 1

        if check_guess(guess, number):
            print(f"Congratulations! You got it after {attempts} attempts.")
            break

    play_again = input("Play again? (yes/no): ")
    if play_again.lower() != "yes":
        print("Thanks for playing!")
        break
# Out:
# ====Welcome to Guesser Game====
# How to play.
# I will select a number and you will have to guess it
# Let's begin!
# Too high
# Too low
# Too low
# Too high
# Too high
# Too low
# Too low
# Correct!
# Congratulations! You got it after 8 attempts.
# Thanks for playing!
